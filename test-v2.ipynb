# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data-v2/inside tank readings/8mm and 6mm leak 100ms div.1ms/8mm and 6mm leak 100ms div.1ms_1.csv",usecols=["Channel A"], low_memory= False)

# %%
data = df.iloc[1:100000]
data = data.astype(float).to_numpy()

# %%
X = data[:,0]
N = len(X)
T = 0.00005000

# %%
Y = X - np.mean(X)

# %%
plt.plot(Y[0:600])
plt.show()
